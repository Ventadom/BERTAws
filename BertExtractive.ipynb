# %%
from summarizer import Summarizer
import os
from nltk import sent_tokenize, word_tokenize
import re 
import numpy as np
import rouge
import time

# %%
def textWordCount(Text):
    number_of_words = word_tokenize(Text)
    count=(len(number_of_words))
    return count

# %%
def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

# %%
def findRatio(count,ratio):
    if(count*ratio<950):
        Ratio=np.round(ratio,3)
        return Ratio
    else:
        return findRatio(count,ratio-0.001)

# %%
def findRatioLong(count,ratio,limit):
    if(count*ratio<limit):
        Ratio=np.round(ratio,3)
        return Ratio
    else:
        return findRatioLong(count,ratio-0.001,limit)

# %%
def shortSentenceClean(Corpus,Limit):
    sentences = sent_tokenize(Corpus)
    for sentence in sentences:
        if (textWordCount(sentence)<Limit):
            sentences.remove(sentence)
#            print("DELETED SHORT SENTENCE, SIZE:",textWordCount(sentence))
#            print(sentence)
            
    newCorpus = ' '.join(sentences)
    return newCorpus

# %%
def longSentenceClean(Corpus,Limit):
    sentences = sent_tokenize(Corpus)
    for sentence in sentences:
        if (textWordCount(sentence)>Limit):
            sentences.remove(sentence)
#            print("****DELETED LONG SENTENCE, SIZE:",textWordCount(sentence))
#            print(sentence)
    
    newCorpus = ' '.join(sentences)
    return newCorpus

# %%
def cleanTitle(Corpus):
    Corpus = Corpus.replace("\n"," ")
    sentences = sent_tokenize(Corpus)
    for sentence in sentences:
        count=0
        for i in sentence:
            if(i.isupper()):
                count=count+1
        if(count*3>len(sentence)):
            sentences.remove(sentence)
            #print(sentence)
            #print("**** DELETED TITLE, SIZE:",textWordCount(sentence))
            #print(sentence)
    
    newCorpus = ' '.join(sentences)
    return newCorpus

# %%
def cleanManyCharacterandNumber(Corpus,rate):
    Corpus = Corpus.replace("\n"," ")
    sentences = sent_tokenize(Corpus)
    for sentence in sentences:        
        digit=letter=other=0
        for c in sentence:
            if c.isdigit():
                digit=digit+1
            elif c.isalpha():
                letter=letter+1
            else:
                other=other+1
        
        if(len(sentence)<(digit*rate)):
            sentences.remove(sentence)
#            print("****DELETED NUMBER, SIZE:",textWordCount(sentence))
#            print(sentence)
            continue
        
        if(len(sentence)<(other-sentence.count(' '))*10):
            sentences.remove(sentence)
#            print("****DELETED CHARACTER, SIZE:",textWordCount(sentence))
#            print(sentence)
        
    newCorpus = ' '.join(sentences)
    return newCorpus

# %%
def cleanParenthesis(Corpus):
    Corpus = Corpus.replace("\n"," ")
    cleaned=[]
    sentences = sent_tokenize(Corpus)
    for sentence in sentences:
        try:
            temp =re.sub("[\(\[].*?[\)\]]", "", sentence) #remove () and []
            cleaned.append(temp)
            #print(sentence)
            #print("---------")
            #print(temp)
            #print("---------------------------------------------")
            continue
        except:
            pass
    
    newCorpus = ' '.join(cleaned)
    #print("---------------------------------------------")
    return newCorpus

# %%
def preProcessingText(Corpus):
    
    cleanedText = Corpus.replace("\n"," ")    
    cleanedText=cleanParenthesis(cleanedText)
    cleanedText=cleanManyCharacterandNumber(cleanedText,10)    
    cleanedText=shortSentenceClean(cleanedText,7)
    cleanedText=longSentenceClean(cleanedText,80)
    
    return cleanedText

# %%
def preProcessingTextLong(Corpus):
    
    cleanedText = Corpus.replace("\n"," ")    
    cleanedText=cleanManyCharacterandNumber(cleanedText,12)    
    cleanedText=shortSentenceClean(cleanedText,6)
    cleanedText=longSentenceClean(cleanedText,40)
    cleanedText=cleanTitle(cleanedText)
    
    return cleanedText

# %%
startTimeforOverall = time.time()
inputs = os.listdir('annual_reports/')
cleanedReports=[]
DocumentSentenceCounts=[]
DocumentWordCounts=[]
AfterPreprocessingDocumentSentenceCounts=[]
AfterPreprocessingDocumentWordCounts=[]
SummarySentenceCounts=[]
SummaryWordCounts=[]

for x in range(len(inputs)):
    startTimeforDocument = time.time()
    #read files
    print('{0}. Document'.format(len(cleanedReports)+1))
    print('File Name:{0}'.format(inputs[x]))
    sourceFilePath='annual_reports/' + inputs[x]
    file = open(sourceFilePath, encoding="utf8")
    temp=file.read()
    file.close()
    
    OrginalTextSentenceCount=textSentenceCount(temp)
    OrginalTextWordCount=textWordCount(temp)
    print('Orginal Text Sentence Count:{0}, Orginal Text Word Count:{1}'.format(OrginalTextSentenceCount,OrginalTextWordCount))
    DocumentSentenceCounts.append(OrginalTextSentenceCount)
    DocumentWordCounts.append(OrginalTextWordCount)
    cleanedReport=preProcessingText(temp)
    
    
    PreprocessedTextLenght=len(cleanedReport)
    print('Text lenght before BERT:{0}'.format(PreprocessedTextLenght))
    
    if(PreprocessedTextLenght>1000000):
        cleanedReport=preProcessingTextLong(cleanedReport)
        PreprocessedTextLenght=len(cleanedReport)
        print('Second Text lenght before BERT:{0}'.format(PreprocessedTextLenght))
    
    cleanedReports.append(cleanedReport)
    PreprocessedTextSentenceCount=textSentenceCount(cleanedReport)
    PreprocessedTextWordCount=textWordCount(cleanedReport)
    #print(cleanedReport)
    print('Preprocessed Text Sentence Count:{0}, Preprocessed Text Word Count:{1}'.format(PreprocessedTextSentenceCount,PreprocessedTextWordCount))
    AfterPreprocessingDocumentSentenceCounts.append(PreprocessedTextSentenceCount)
    AfterPreprocessingDocumentWordCounts.append(PreprocessedTextWordCount)
    
    #BERT

    Ratio=findRatio(PreprocessedTextWordCount,1)
    print('Ratio:',Ratio)
    if (Ratio<=0.0):
        Ratio=0.001
        print('Second Ratio:',Ratio)
    model = Summarizer()
    result = model(cleanedReport,ratio=Ratio)
    summary = ''.join(result)
    #write
    destinationFilePath='summaries/' + inputs[x]
    file2 = open(destinationFilePath,"w",encoding='utf-8') 
    file2.write(summary)
    file2.close()
    SummaryTextSentenceCount=textSentenceCount(summary)
    SummaryTextWordCount=textWordCount(summary)
    print('Summary Sentence Count:{0}, Summary Word Count:{1}'.format(SummaryTextSentenceCount,SummaryTextWordCount))
    SummarySentenceCounts.append(SummaryTextSentenceCount)
    SummaryWordCounts.append(SummaryTextWordCount)
    
    Limit=930
    while True:        
        if(SummaryTextWordCount>999):
            if(SummaryTextWordCount>900 and SummaryTextWordCount<1100):
                Ratio=Ratio-0.001
            else:
                Ratio=Ratio-0.003
            Ratio=findRatioLong(PreprocessedTextWordCount,Ratio,Limit)
            print('Summary Word Limit:',Limit)
            print('New Ratio:',Ratio)
            if (Ratio<=0.0):
                Ratio=0.001
                print('New Ratio:',Ratio)
            model = Summarizer()
            result = model(cleanedReport,ratio=Ratio)
            summary = ''.join(result)
            #write
            destinationFilePath='summaries/' + inputs[x]
            file2 = open(destinationFilePath,"w",encoding='utf-8') 
            file2.write(summary)
            file2.close()
            SummaryTextSentenceCount=textSentenceCount(summary)
            SummaryTextWordCount=textWordCount(summary)
            print('New Summary Sentence Count:{0}, Summary Word Count:{1}'.format(SummaryTextSentenceCount,SummaryTextWordCount))
            SummarySentenceCounts.pop()
            SummaryWordCounts.pop()
            SummarySentenceCounts.append(SummaryTextSentenceCount)
            SummaryWordCounts.append(SummaryTextWordCount)
            Limit=Limit-20
        else:
            break
    
    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))
    print("######################################################################################")
# Out:
# 1. Document
# File Name:10023.txt
# Orginal Text Sentence Count:937, Orginal Text Word Count:35691
# Text lenght before BERT:139845
# Preprocessed Text Sentence Count:813, Preprocessed Text Word Count:23703
# Ratio: 0.04
# Summary Sentence Count:32, Summary Word Count:1237
# Summary Word Limit: 930
# New Ratio: 0.037
# New Summary Sentence Count:30, Summary Word Count:1028
# Summary Word Limit: 910
# New Ratio: 0.036
# New Summary Sentence Count:28, Summary Word Count:978
# Document processing time: 08:15
# Total processing time: 01:00:08:15
# ######################################################################################
# 2. Document
# File Name:10024.txt
# Orginal Text Sentence Count:947, Orginal Text Word Count:37399
# Text lenght before BERT:140583
# Preprocessed Text Sentence Count:821, Preprocessed Text Word Count:23970
# Ratio: 0.039
# Summary Sentence Count:33, Summary Word Count:1114
# Summary Word Limit: 930
# New Ratio: 0.036
# New Summary Sentence Count:30, Summary Word Count:940
# Document processing time: 05:35
# Total processing time: 01:00:13:50
# ######################################################################################
# 3. Document
# File Name:10025.txt
# Orginal Text Sentence Count:1067, Orginal Text Word Count:42433
# Text lenght before BERT:165261
# Preprocessed Text Sentence Count:937, Preprocessed Text Word Count:28235
# Ratio: 0.033
# Summary Sentence Count:31, Summary Word Count:1021
# Summary Word Limit: 930
# New Ratio: 0.032
# New Summary Sentence Count:30, Summary Word Count:1041
# Summary Word Limit: 910
# New Ratio: 0.031
# New Summary Sentence Count:29, Summary Word Count:1010
# Summary Word Limit: 890
# New Ratio: 0.03
# New Summary Sentence Count:29, Summary Word Count:1110
# Summary Word Limit: 870
# New Ratio: 0.027
# New Summary Sentence Count:25, Summary Word Count:855
# Document processing time: 15:46
# Total processing time: 01:00:29:37
# ######################################################################################
# 4. Document
# File Name:10050.txt
# Orginal Text Sentence Count:2251, Orginal Text Word Count:83104
# Text lenght before BERT:331262
# Preprocessed Text Sentence Count:1980, Preprocessed Text Word Count:55240
# Ratio: 0.017
# Summary Sentence Count:33, Summary Word Count:1255
# Summary Word Limit: 930
# New Ratio: 0.014
# New Summary Sentence Count:28, Summary Word Count:960
# Document processing time: 12:41
# Total processing time: 01:00:42:18
# ######################################################################################
# 5. Document
# File Name:10051.txt
# Orginal Text Sentence Count:2587, Orginal Text Word Count:114641
# Text lenght before BERT:363445
# Preprocessed Text Sentence Count:2100, Preprocessed Text Word Count:65909
# Ratio: 0.014
# Summary Sentence Count:29, Summary Word Count:1192
# Summary Word Limit: 930
# New Ratio: 0.011
# New Summary Sentence Count:23, Summary Word Count:911
# Document processing time: 14:11
# Total processing time: 01:00:56:29
# ######################################################################################
# 6. Document
# File Name:10063.txt
# Orginal Text Sentence Count:1047, Orginal Text Word Count:39141
# Text lenght before BERT:162816
# Preprocessed Text Sentence Count:948, Preprocessed Text Word Count:27691
# Ratio: 0.034
# Summary Sentence Count:33, Summary Word Count:952
# Document processing time: 03:08
# Total processing time: 01:00:59:38
# ######################################################################################
# 7. Document
# File Name:10064.txt
# Orginal Text Sentence Count:1276, Orginal Text Word Count:49945
# Text lenght before BERT:187118
# Preprocessed Text Sentence Count:1113, Preprocessed Text Word Count:31862
# Ratio: 0.029
# Summary Sentence Count:33, Summary Word Count:1104
# Summary Word Limit: 930
# New Ratio: 0.026
# New Summary Sentence Count:29, Summary Word Count:896
# Document processing time: 07:30
# Total processing time: 01:01:07:08
# ######################################################################################
# 8. Document
# File Name:10065.txt
# Orginal Text Sentence Count:1568, Orginal Text Word Count:58426
# Text lenght before BERT:235103
# Preprocessed Text Sentence Count:1416, Preprocessed Text Word Count:40002
# Ratio: 0.023
# Summary Sentence Count:33, Summary Word Count:1047
# Summary Word Limit: 930
# New Ratio: 0.022
# New Summary Sentence Count:31, Summary Word Count:1000
# Summary Word Limit: 910
# New Ratio: 0.021
# New Summary Sentence Count:30, Summary Word Count:994
# Document processing time: 13:48
# Total processing time: 01:01:20:57
# ######################################################################################
# 9. Document
# File Name:10066.txt
# Orginal Text Sentence Count:1698, Orginal Text Word Count:63693
# Text lenght before BERT:265657
# Preprocessed Text Sentence Count:1513, Preprocessed Text Word Count:44363
# Ratio: 0.021
# Summary Sentence Count:31, Summary Word Count:1149
# Summary Word Limit: 930
# New Ratio: 0.018
# New Summary Sentence Count:27, Summary Word Count:969
# Document processing time: 09:38
# Total processing time: 01:01:30:35
# ######################################################################################
# 10. Document
# File Name:10067.txt
# Orginal Text Sentence Count:1685, Orginal Text Word Count:62318
# Text lenght before BERT:264506
# Preprocessed Text Sentence Count:1491, Preprocessed Text Word Count:44250
# Ratio: 0.021
# Summary Sentence Count:32, Summary Word Count:1144
# Summary Word Limit: 930
# New Ratio: 0.018
# New Summary Sentence Count:27, Summary Word Count:906
# Document processing time: 09:52
# Total processing time: 01:01:40:27
# ######################################################################################
# 11. Document
# File Name:10068.txt
# Orginal Text Sentence Count:2138, Orginal Text Word Count:75319
# Text lenght before BERT:309738
# Preprocessed Text Sentence Count:1836, Preprocessed Text Word Count:52474
# Ratio: 0.018
# Summary Sentence Count:34, Summary Word Count:1077
# Summary Word Limit: 930
# New Ratio: 0.017
# New Summary Sentence Count:31, Summary Word Count:978
# Document processing time: 11:43
# Total processing time: 01:01:52:10
# ######################################################################################
# 12. Document
# File Name:10069.txt
# Orginal Text Sentence Count:2396, Orginal Text Word Count:79841
# Text lenght before BERT:349440
# Preprocessed Text Sentence Count:2121, Preprocessed Text Word Count:58638
# Ratio: 0.016
# Summary Sentence Count:33, Summary Word Count:1122
# Summary Word Limit: 930
# New Ratio: 0.013
# New Summary Sentence Count:28, Summary Word Count:969
# Document processing time: 13:46
# Total processing time: 01:02:05:57
# ######################################################################################
# 13. Document
# File Name:1007.txt
# Orginal Text Sentence Count:1765, Orginal Text Word Count:62884
# Text lenght before BERT:251102
# Preprocessed Text Sentence Count:1551, Preprocessed Text Word Count:43061
# Ratio: 0.022
# Summary Sentence Count:35, Summary Word Count:1108
# Summary Word Limit: 930
# New Ratio: 0.019
# New Summary Sentence Count:31, Summary Word Count:1142
# Summary Word Limit: 910
# New Ratio: 0.016
# New Summary Sentence Count:26, Summary Word Count:861
# Document processing time: 14:42
# Total processing time: 01:02:20:40
# ######################################################################################
# 14. Document
# File Name:10070.txt
# Orginal Text Sentence Count:3005, Orginal Text Word Count:103314
# Text lenght before BERT:452516
# Preprocessed Text Sentence Count:2636, Preprocessed Text Word Count:75336
# Ratio: 0.012
# Summary Sentence Count:31, Summary Word Count:1123
# Summary Word Limit: 930
# New Ratio: 0.009
# New Summary Sentence Count:23, Summary Word Count:815
# Document processing time: 16:44
# Total processing time: 01:02:37:25
# ######################################################################################
# 15. Document
# File Name:10071.txt
# Orginal Text Sentence Count:2738, Orginal Text Word Count:95891
# Text lenght before BERT:421004
# Preprocessed Text Sentence Count:2364, Preprocessed Text Word Count:69753
# Ratio: 0.013
# Summary Sentence Count:32, Summary Word Count:1196
# Summary Word Limit: 930
# New Ratio: 0.01
# New Summary Sentence Count:24, Summary Word Count:947
# Document processing time: 15:08
# Total processing time: 01:02:52:34
# ######################################################################################
# 16. Document
# File Name:10073.txt
# Orginal Text Sentence Count:603, Orginal Text Word Count:23967
# Text lenght before BERT:82440
# Preprocessed Text Sentence Count:520, Preprocessed Text Word Count:14179
# Ratio: 0.067
# Summary Sentence Count:35, Summary Word Count:914
# Document processing time: 01:44
# Total processing time: 01:02:54:18
# ######################################################################################
# 17. Document
# File Name:1008.txt
# Orginal Text Sentence Count:1679, Orginal Text Word Count:62261
# Text lenght before BERT:254753
# Preprocessed Text Sentence Count:1455, Preprocessed Text Word Count:43850
# Ratio: 0.021
# Summary Sentence Count:30, Summary Word Count:1092
# Summary Word Limit: 930
# New Ratio: 0.02
# New Summary Sentence Count:28, Summary Word Count:986
# Document processing time: 09:27
# Total processing time: 01:03:03:46
# ######################################################################################
# 18. Document
# File Name:10120.txt
# Orginal Text Sentence Count:493, Orginal Text Word Count:18606
# Text lenght before BERT:71614
# Preprocessed Text Sentence Count:440, Preprocessed Text Word Count:12180
# Ratio: 0.077
# Summary Sentence Count:32, Summary Word Count:933
# Document processing time: 01:26
# Total processing time: 01:03:05:12
# ######################################################################################
# 19. Document
# File Name:10121.txt
# Orginal Text Sentence Count:791, Orginal Text Word Count:29395
# Text lenght before BERT:102035
# Preprocessed Text Sentence Count:667, Preprocessed Text Word Count:17389
# Ratio: 0.054
# Summary Sentence Count:36, Summary Word Count:977
# Document processing time: 02:09
# Total processing time: 01:03:07:22
# ######################################################################################
# 20. Document
# File Name:10122.txt
# Orginal Text Sentence Count:1006, Orginal Text Word Count:36826
# Text lenght before BERT:143765
# Preprocessed Text Sentence Count:900, Preprocessed Text Word Count:24287
# Ratio: 0.039
# Summary Sentence Count:35, Summary Word Count:1057
# Summary Word Limit: 930
# New Ratio: 0.038
# New Summary Sentence Count:35, Summary Word Count:1018
# Summary Word Limit: 910
# New Ratio: 0.037
# New Summary Sentence Count:34, Summary Word Count:1100
# Summary Word Limit: 890
# New Ratio: 0.034
# New Summary Sentence Count:32, Summary Word Count:1056
# Summary Word Limit: 870
# New Ratio: 0.033
# New Summary Sentence Count:31, Summary Word Count:1028
# Summary Word Limit: 850
# New Ratio: 0.032
# New Summary Sentence Count:30, Summary Word Count:942
# Document processing time: 17:28
# Total processing time: 01:03:24:50
# ######################################################################################
# 21. Document
# File Name:10123.txt
# Orginal Text Sentence Count:1243, Orginal Text Word Count:47613
# Text lenght before BERT:169958
# Preprocessed Text Sentence Count:1080, Preprocessed Text Word Count:28427
# Ratio: 0.033
# Summary Sentence Count:36, Summary Word Count:999
# Document processing time: 03:30
# Total processing time: 01:03:28:21
# ######################################################################################
# 22. Document
# File Name:1013.txt
# Orginal Text Sentence Count:560, Orginal Text Word Count:22469
# Text lenght before BERT:77188
# Preprocessed Text Sentence Count:456, Preprocessed Text Word Count:12977
# Ratio: 0.073
# Summary Sentence Count:34, Summary Word Count:1024
# Summary Word Limit: 930
# New Ratio: 0.071
# New Summary Sentence Count:32, Summary Word Count:1044
# Summary Word Limit: 910
# New Ratio: 0.07
# New Summary Sentence Count:32, Summary Word Count:979
# Document processing time: 04:43
# Total processing time: 01:03:33:04
# ######################################################################################
# 23. Document
# File Name:1014.txt
# Orginal Text Sentence Count:502, Orginal Text Word Count:20856
# Text lenght before BERT:75146
# Preprocessed Text Sentence Count:433, Preprocessed Text Word Count:12459
# Ratio: 0.076
# Summary Sentence Count:33, Summary Word Count:938
# Document processing time: 01:29
# Total processing time: 01:03:34:34
# ######################################################################################
# 24. Document
# File Name:1015.txt
# Orginal Text Sentence Count:511, Orginal Text Word Count:19867
# Text lenght before BERT:71200
# Preprocessed Text Sentence Count:424, Preprocessed Text Word Count:11791
# Ratio: 0.08
# Summary Sentence Count:33, Summary Word Count:918
# Document processing time: 01:27
# Total processing time: 01:03:36:02
# ######################################################################################
# 25. Document
# File Name:1016.txt
# Orginal Text Sentence Count:577, Orginal Text Word Count:22592
# Text lenght before BERT:87465
# Preprocessed Text Sentence Count:496, Preprocessed Text Word Count:14527
# Ratio: 0.065
# Summary Sentence Count:33, Summary Word Count:1118
# Summary Word Limit: 930
# New Ratio: 0.062
# New Summary Sentence Count:31, Summary Word Count:1005
# Summary Word Limit: 910
# New Ratio: 0.061
# New Summary Sentence Count:31, Summary Word Count:1005
# Summary Word Limit: 890
# New Ratio: 0.06
# New Summary Sentence Count:30, Summary Word Count:1080
# Summary Word Limit: 870
# New Ratio: 0.059
# New Summary Sentence Count:30, Summary Word Count:1080
# Summary Word Limit: 850
# New Ratio: 0.058
# New Summary Sentence Count:29, Summary Word Count:990
# Document processing time: 12:14
# Total processing time: 01:03:48:16
# ######################################################################################
# 26. Document
# File Name:10196.txt
# Orginal Text Sentence Count:832, Orginal Text Word Count:31355
# Text lenght before BERT:124870
# Preprocessed Text Sentence Count:739, Preprocessed Text Word Count:21006
# Ratio: 0.045
# Summary Sentence Count:34, Summary Word Count:974
# Document processing time: 02:27
# Total processing time: 01:03:50:44
# ######################################################################################
# 27. Document
# File Name:10197.txt
# Orginal Text Sentence Count:910, Orginal Text Word Count:33759
# Text lenght before BERT:134817
# Preprocessed Text Sentence Count:825, Preprocessed Text Word Count:22843
# Ratio: 0.041
# Summary Sentence Count:34, Summary Word Count:992
# Document processing time: 02:45
# Total processing time: 01:03:53:29
# ######################################################################################
# 28. Document
# File Name:10199.txt
# Orginal Text Sentence Count:1049, Orginal Text Word Count:39496
# Text lenght before BERT:156674
# Preprocessed Text Sentence Count:957, Preprocessed Text Word Count:26547
# Ratio: 0.035
# Summary Sentence Count:35, Summary Word Count:1029
# Summary Word Limit: 930
# New Ratio: 0.034
# New Summary Sentence Count:34, Summary Word Count:970
# Document processing time: 06:26
# Total processing time: 01:03:59:55
# ######################################################################################
# 29. Document
# File Name:102.txt
# Orginal Text Sentence Count:823, Orginal Text Word Count:28373
# Text lenght before BERT:113445
# Preprocessed Text Sentence Count:679, Preprocessed Text Word Count:19006
# Ratio: 0.049
# Summary Sentence Count:32, Summary Word Count:969
# Document processing time: 02:16
# Total processing time: 01:04:02:12
# ######################################################################################
# 30. Document
# File Name:10200.txt
# Orginal Text Sentence Count:1049, Orginal Text Word Count:41016
# Text lenght before BERT:161343
# Preprocessed Text Sentence Count:940, Preprocessed Text Word Count:27403
# Ratio: 0.034
# Summary Sentence Count:33, Summary Word Count:1007
# Summary Word Limit: 930
# New Ratio: 0.033
# New Summary Sentence Count:32, Summary Word Count:1132
# Summary Word Limit: 910
# New Ratio: 0.03
# New Summary Sentence Count:28, Summary Word Count:968
# Document processing time: 09:25
# Total processing time: 01:04:11:38
# ######################################################################################
# 31. Document
# File Name:1022.txt
# Orginal Text Sentence Count:1172, Orginal Text Word Count:47971
# Text lenght before BERT:170445
# Preprocessed Text Sentence Count:1052, Preprocessed Text Word Count:28916
# Ratio: 0.032
# Summary Sentence Count:34, Summary Word Count:1100
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:31, Summary Word Count:1053
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:31, Summary Word Count:1023
# Summary Word Limit: 890
# New Ratio: 0.027
# New Summary Sentence Count:30, Summary Word Count:1009
# Summary Word Limit: 870
# New Ratio: 0.026
# New Summary Sentence Count:27, Summary Word Count:854
# Document processing time: 17:19
# Total processing time: 01:04:28:58
# ######################################################################################
# 32. Document
# File Name:10225.txt
# Orginal Text Sentence Count:503, Orginal Text Word Count:18504
# Text lenght before BERT:79248
# Preprocessed Text Sentence Count:448, Preprocessed Text Word Count:13475
# Ratio: 0.07
# Summary Sentence Count:32, Summary Word Count:975
# Document processing time: 01:33
# Total processing time: 01:04:30:31
# ######################################################################################
# 33. Document
# File Name:10226.txt
# Orginal Text Sentence Count:575, Orginal Text Word Count:20423
# Text lenght before BERT:84655
# Preprocessed Text Sentence Count:497, Preprocessed Text Word Count:14336
# Ratio: 0.066
# Summary Sentence Count:33, Summary Word Count:954
# Document processing time: 01:41
# Total processing time: 01:04:32:13
# ######################################################################################
# 34. Document
# File Name:10227.txt
# Orginal Text Sentence Count:593, Orginal Text Word Count:20794
# Text lenght before BERT:86113
# Preprocessed Text Sentence Count:507, Preprocessed Text Word Count:14578
# Ratio: 0.065
# Summary Sentence Count:33, Summary Word Count:963
# Document processing time: 01:45
# Total processing time: 01:04:33:59
# ######################################################################################
# 35. Document
# File Name:1023.txt
# Orginal Text Sentence Count:1213, Orginal Text Word Count:54187
# Text lenght before BERT:188721
# Preprocessed Text Sentence Count:1086, Preprocessed Text Word Count:32897
# Ratio: 0.028
# Summary Sentence Count:32, Summary Word Count:1038
# Summary Word Limit: 930
# New Ratio: 0.027
# New Summary Sentence Count:31, Summary Word Count:1127
# Summary Word Limit: 910
# New Ratio: 0.024
# New Summary Sentence Count:26, Summary Word Count:1065
# Summary Word Limit: 890
# New Ratio: 0.023
# New Summary Sentence Count:25, Summary Word Count:955
# Document processing time: 14:40
# Total processing time: 01:04:48:39
# ######################################################################################
# 36. Document
# File Name:10238.txt
# Orginal Text Sentence Count:727, Orginal Text Word Count:28473
# Text lenght before BERT:114478
# Preprocessed Text Sentence Count:649, Preprocessed Text Word Count:18808
# Ratio: 0.05
# Summary Sentence Count:32, Summary Word Count:971
# Document processing time: 02:11
# Total processing time: 01:04:50:51
# ######################################################################################
# 37. Document
# File Name:1024.txt
# Orginal Text Sentence Count:1267, Orginal Text Word Count:53876
# Text lenght before BERT:186190
# Preprocessed Text Sentence Count:1135, Preprocessed Text Word Count:31973
# Ratio: 0.029
# Summary Sentence Count:33, Summary Word Count:1103
# Summary Word Limit: 930
# New Ratio: 0.026
# New Summary Sentence Count:30, Summary Word Count:1118
# Summary Word Limit: 910
# New Ratio: 0.023
# New Summary Sentence Count:26, Summary Word Count:854
# Document processing time: 11:22
# Total processing time: 01:05:02:13
# ######################################################################################
# 38. Document
# File Name:1025.txt
# Orginal Text Sentence Count:1499, Orginal Text Word Count:56136
# Text lenght before BERT:215243
# Preprocessed Text Sentence Count:1345, Preprocessed Text Word Count:36583
# Ratio: 0.025
# Summary Sentence Count:35, Summary Word Count:1169
# Summary Word Limit: 930
# New Ratio: 0.022
# New Summary Sentence Count:31, Summary Word Count:1053
# Summary Word Limit: 910
# New Ratio: 0.021
# New Summary Sentence Count:28, Summary Word Count:829
# Document processing time: 13:07
# Total processing time: 01:05:15:20
# ######################################################################################
# 39. Document
# File Name:1026.txt
# Orginal Text Sentence Count:1532, Orginal Text Word Count:57313
# Text lenght before BERT:223269
# Preprocessed Text Sentence Count:1380, Preprocessed Text Word Count:37951
# Ratio: 0.025
# Summary Sentence Count:35, Summary Word Count:1065
# Summary Word Limit: 930
# New Ratio: 0.024
# New Summary Sentence Count:36, Summary Word Count:1015
# Summary Word Limit: 910
# New Ratio: 0.023
# New Summary Sentence Count:34, Summary Word Count:1062
# Summary Word Limit: 890
# New Ratio: 0.022
# New Summary Sentence Count:31, Summary Word Count:933
# Document processing time: 18:00
# Total processing time: 01:05:33:21
# ######################################################################################
# 40. Document
# File Name:1027.txt
# Orginal Text Sentence Count:1576, Orginal Text Word Count:57998
# Text lenght before BERT:231183
# Preprocessed Text Sentence Count:1421, Preprocessed Text Word Count:39218
# Ratio: 0.024
# Summary Sentence Count:36, Summary Word Count:1084
# Summary Word Limit: 930
# New Ratio: 0.023
# New Summary Sentence Count:34, Summary Word Count:1170
# Summary Word Limit: 910
# New Ratio: 0.02
# New Summary Sentence Count:32, Summary Word Count:982
# Document processing time: 14:05
# Total processing time: 01:05:47:26
# ######################################################################################
# 41. Document
# File Name:10368.txt
# Orginal Text Sentence Count:1656, Orginal Text Word Count:63559
# Text lenght before BERT:253266
# Preprocessed Text Sentence Count:1500, Preprocessed Text Word Count:42571
# Ratio: 0.022
# Summary Sentence Count:35, Summary Word Count:1068
# Summary Word Limit: 930
# New Ratio: 0.021
# New Summary Sentence Count:33, Summary Word Count:1011
# Summary Word Limit: 910
# New Ratio: 0.02
# New Summary Sentence Count:31, Summary Word Count:948
# Document processing time: 19:48
# Total processing time: 01:06:07:14
# ######################################################################################
# 42. Document
# File Name:10371.txt
# Orginal Text Sentence Count:2086, Orginal Text Word Count:72731
# Text lenght before BERT:314756
# Preprocessed Text Sentence Count:1887, Preprocessed Text Word Count:52080
# Ratio: 0.018
# Summary Sentence Count:34, Summary Word Count:1108
# Summary Word Limit: 930
# New Ratio: 0.015
# New Summary Sentence Count:29, Summary Word Count:1078
# Summary Word Limit: 910
# New Ratio: 0.014
# New Summary Sentence Count:27, Summary Word Count:902
# Document processing time: 20:31
# Total processing time: 01:06:27:45
# ######################################################################################
# 43. Document
# File Name:10376.txt
# Orginal Text Sentence Count:2483, Orginal Text Word Count:86462
# Text lenght before BERT:375884
# Preprocessed Text Sentence Count:2232, Preprocessed Text Word Count:64790
# Ratio: 0.014
# Summary Sentence Count:33, Summary Word Count:1084
# Summary Word Limit: 930
# New Ratio: 0.013
# New Summary Sentence Count:31, Summary Word Count:1126
# Summary Word Limit: 910
# New Ratio: 0.01
# New Summary Sentence Count:24, Summary Word Count:769
# Document processing time: 24:25
# Total processing time: 01:06:52:11
# ######################################################################################
# 44. Document
# File Name:10382.txt
# Orginal Text Sentence Count:2012, Orginal Text Word Count:66955
# Text lenght before BERT:284668
# Preprocessed Text Sentence Count:1783, Preprocessed Text Word Count:48618
# Ratio: 0.019
# Summary Sentence Count:33, Summary Word Count:1106
# Summary Word Limit: 930
# New Ratio: 0.016
# New Summary Sentence Count:28, Summary Word Count:1040
# Summary Word Limit: 910
# New Ratio: 0.015
# New Summary Sentence Count:27, Summary Word Count:899
# Document processing time: 18:48
# Total processing time: 01:07:11:00
# ######################################################################################
# 45. Document
# File Name:10383.txt
# Orginal Text Sentence Count:2195, Orginal Text Word Count:73513
# Text lenght before BERT:206856
# Preprocessed Text Sentence Count:1232, Preprocessed Text Word Count:34945
# Ratio: 0.027
# Summary Sentence Count:32, Summary Word Count:1057
# Summary Word Limit: 930
# New Ratio: 0.026
# New Summary Sentence Count:34, Summary Word Count:1044
# Summary Word Limit: 910
# New Ratio: 0.025
# New Summary Sentence Count:31, Summary Word Count:1067
# Summary Word Limit: 890
# New Ratio: 0.024
# New Summary Sentence Count:29, Summary Word Count:986
# Document processing time: 17:29
# Total processing time: 01:07:28:29
# ######################################################################################
# 46. Document
# File Name:10385.txt
# Orginal Text Sentence Count:627, Orginal Text Word Count:23167
# Text lenght before BERT:87909
# Preprocessed Text Sentence Count:557, Preprocessed Text Word Count:15112
# Ratio: 0.062
# Summary Sentence Count:36, Summary Word Count:989
# Document processing time: 01:59
# Total processing time: 01:07:30:29
# ######################################################################################
# 47. Document
# File Name:10386.txt
# Orginal Text Sentence Count:782, Orginal Text Word Count:27369
# Text lenght before BERT:103855
# Preprocessed Text Sentence Count:714, Preprocessed Text Word Count:17887
# Ratio: 0.053
# Summary Sentence Count:38, Summary Word Count:985
# Document processing time: 02:29
# Total processing time: 01:07:32:58
# ######################################################################################
# 48. Document
# File Name:10387.txt
# Orginal Text Sentence Count:1008, Orginal Text Word Count:34096
# Text lenght before BERT:135787
# Preprocessed Text Sentence Count:897, Preprocessed Text Word Count:23395
# Ratio: 0.04
# Summary Sentence Count:37, Summary Word Count:1210
# Summary Word Limit: 930
# New Ratio: 0.037
# New Summary Sentence Count:35, Summary Word Count:943
# Document processing time: 06:18
# Total processing time: 01:07:39:17
# ######################################################################################
# 49. Document
# File Name:10388.txt
# Orginal Text Sentence Count:1521, Orginal Text Word Count:46782
# Text lenght before BERT:203661
# Preprocessed Text Sentence Count:1302, Preprocessed Text Word Count:35282
# Ratio: 0.026
# Summary Sentence Count:34, Summary Word Count:1029
# Summary Word Limit: 930
# New Ratio: 0.025
# New Summary Sentence Count:32, Summary Word Count:1035
# Summary Word Limit: 910
# New Ratio: 0.024
# New Summary Sentence Count:31, Summary Word Count:1038
# Summary Word Limit: 890
# New Ratio: 0.023
# New Summary Sentence Count:30, Summary Word Count:970
# Document processing time: 18:30
# Total processing time: 01:07:57:47
# ######################################################################################
# 50. Document
# File Name:10390.txt
# Orginal Text Sentence Count:1589, Orginal Text Word Count:54649
# Text lenght before BERT:241732
# Preprocessed Text Sentence Count:1444, Preprocessed Text Word Count:41108
# Ratio: 0.023
# Summary Sentence Count:33, Summary Word Count:1102
# Summary Word Limit: 930
# New Ratio: 0.02
# New Summary Sentence Count:29, Summary Word Count:961
# Document processing time: 10:23
# Total processing time: 01:08:08:11
# ######################################################################################
# 51. Document
# File Name:10391.txt
# Orginal Text Sentence Count:1736, Orginal Text Word Count:57944
# Text lenght before BERT:257636
# Preprocessed Text Sentence Count:1554, Preprocessed Text Word Count:43262
# Ratio: 0.021
# Summary Sentence Count:33, Summary Word Count:1004
# Summary Word Limit: 930
# New Ratio: 0.02
# New Summary Sentence Count:31, Summary Word Count:878
# Document processing time: 11:13
# Total processing time: 01:08:19:24
# ######################################################################################
# 52. Document
# File Name:10392.txt
# Orginal Text Sentence Count:1645, Orginal Text Word Count:56942
# Text lenght before BERT:241808
# Preprocessed Text Sentence Count:1437, Preprocessed Text Word Count:40128
# Ratio: 0.023
# Summary Sentence Count:32, Summary Word Count:1016
# Summary Word Limit: 930
# New Ratio: 0.022
# New Summary Sentence Count:31, Summary Word Count:995
# Document processing time: 10:01
# Total processing time: 01:08:29:26
# ######################################################################################
# 53. Document
# File Name:10393.txt
# Orginal Text Sentence Count:1930, Orginal Text Word Count:64081
# Text lenght before BERT:279280
# Preprocessed Text Sentence Count:1687, Preprocessed Text Word Count:47024
# Ratio: 0.02
# Summary Sentence Count:33, Summary Word Count:1062
# Summary Word Limit: 930
# New Ratio: 0.019
# New Summary Sentence Count:31, Summary Word Count:987
# Document processing time: 11:57
# Total processing time: 01:08:41:23
# ######################################################################################
# 54. Document
# File Name:10394.txt
# Orginal Text Sentence Count:1809, Orginal Text Word Count:63097
# Text lenght before BERT:274207
# Preprocessed Text Sentence Count:1609, Preprocessed Text Word Count:46251
# Ratio: 0.02
# Summary Sentence Count:32, Summary Word Count:1034
# Summary Word Limit: 930
# New Ratio: 0.019
# New Summary Sentence Count:30, Summary Word Count:1102
# Summary Word Limit: 910
# New Ratio: 0.016
# New Summary Sentence Count:26, Summary Word Count:890
# Document processing time: 17:03
# Total processing time: 01:08:58:27
# ######################################################################################
# 55. Document
# File Name:104.txt
# Orginal Text Sentence Count:1401, Orginal Text Word Count:47130
# Text lenght before BERT:204913
# Preprocessed Text Sentence Count:1266, Preprocessed Text Word Count:35453
# Ratio: 0.026
# Summary Sentence Count:33, Summary Word Count:1104
# Summary Word Limit: 930
# New Ratio: 0.023
# New Summary Sentence Count:29, Summary Word Count:1081
# Summary Word Limit: 910
# New Ratio: 0.022
# New Summary Sentence Count:28, Summary Word Count:1021
# Summary Word Limit: 890
# New Ratio: 0.021
# New Summary Sentence Count:27, Summary Word Count:901
# Document processing time: 17:57
# Total processing time: 01:09:16:25
# ######################################################################################
# 56. Document
# File Name:10419.txt
# Orginal Text Sentence Count:2922, Orginal Text Word Count:93646
# Text lenght before BERT:411152
# Preprocessed Text Sentence Count:2614, Preprocessed Text Word Count:71698
# Ratio: 0.013
# Summary Sentence Count:34, Summary Word Count:1072
# Summary Word Limit: 930
# New Ratio: 0.012
# New Summary Sentence Count:31, Summary Word Count:968
# Document processing time: 18:48
# Total processing time: 01:09:35:13
# ######################################################################################
# 57. Document
# File Name:1044.txt
# Orginal Text Sentence Count:620, Orginal Text Word Count:22630
# Text lenght before BERT:88485
# Preprocessed Text Sentence Count:508, Preprocessed Text Word Count:15232
# Ratio: 0.062
# Summary Sentence Count:32, Summary Word Count:972
# Document processing time: 01:57
# Total processing time: 01:09:37:10
# ######################################################################################
# 58. Document
# File Name:1045.txt
# Orginal Text Sentence Count:562, Orginal Text Word Count:20439
# Text lenght before BERT:80173
# Preprocessed Text Sentence Count:473, Preprocessed Text Word Count:13803
# Ratio: 0.068
# Summary Sentence Count:32, Summary Word Count:916
# Document processing time: 01:52
# Total processing time: 01:09:39:03
# ######################################################################################
# 59. Document
# File Name:1046.txt
# Orginal Text Sentence Count:573, Orginal Text Word Count:20106
# Text lenght before BERT:80945
# Preprocessed Text Sentence Count:490, Preprocessed Text Word Count:13971
# Ratio: 0.067
# Summary Sentence Count:33, Summary Word Count:1017
# Summary Word Limit: 930
# New Ratio: 0.066
# New Summary Sentence Count:32, Summary Word Count:973
# Document processing time: 03:45
# Total processing time: 01:09:42:49
# ######################################################################################
# 60. Document
# File Name:105.txt
# Orginal Text Sentence Count:1317, Orginal Text Word Count:46608
# Text lenght before BERT:185982
# Preprocessed Text Sentence Count:1163, Preprocessed Text Word Count:31510
# Ratio: 0.03
# Summary Sentence Count:35, Summary Word Count:972
# Document processing time: 04:07
# Total processing time: 01:09:46:56
# ######################################################################################
# 61. Document
# File Name:10500.txt
# Orginal Text Sentence Count:1165, Orginal Text Word Count:38547
# Text lenght before BERT:176541
# Preprocessed Text Sentence Count:1038, Preprocessed Text Word Count:29641
# Ratio: 0.032
# Summary Sentence Count:33, Summary Word Count:1066
# Summary Word Limit: 930
# New Ratio: 0.031
# New Summary Sentence Count:32, Summary Word Count:1070
# Summary Word Limit: 910
# New Ratio: 0.03
# New Summary Sentence Count:31, Summary Word Count:1086
# Summary Word Limit: 890
# New Ratio: 0.029
# New Summary Sentence Count:30, Summary Word Count:1063
# Summary Word Limit: 870
# New Ratio: 0.028
# New Summary Sentence Count:29, Summary Word Count:971
# Document processing time: 19:22
# Total processing time: 01:10:06:18
# ######################################################################################
# 62. Document
# File Name:10501.txt
# Orginal Text Sentence Count:1293, Orginal Text Word Count:44187
# Text lenght before BERT:198311
# Preprocessed Text Sentence Count:1179, Preprocessed Text Word Count:33475
# Ratio: 0.028
# Summary Sentence Count:33, Summary Word Count:992
# Document processing time: 04:19
# Total processing time: 01:10:10:37
# ######################################################################################
# 63. Document
# File Name:10502.txt
# Orginal Text Sentence Count:1233, Orginal Text Word Count:46450
# Text lenght before BERT:183467
# Preprocessed Text Sentence Count:1100, Preprocessed Text Word Count:30635
# Ratio: 0.031
# Summary Sentence Count:33, Summary Word Count:1122
# Summary Word Limit: 930
# New Ratio: 0.028
# New Summary Sentence Count:30, Summary Word Count:1011
# Summary Word Limit: 910
# New Ratio: 0.027
# New Summary Sentence Count:29, Summary Word Count:897
# Document processing time: 12:33
# Total processing time: 01:10:23:10
# ######################################################################################
# 64. Document
# File Name:10503.txt
# Orginal Text Sentence Count:1128, Orginal Text Word Count:47971
# Text lenght before BERT:176667
# Preprocessed Text Sentence Count:1017, Preprocessed Text Word Count:29574
# Ratio: 0.032
# Summary Sentence Count:33, Summary Word Count:1165
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:30, Summary Word Count:1002
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:28, Summary Word Count:935
# Document processing time: 11:49
# Total processing time: 01:10:35:00
# ######################################################################################
# 65. Document
# File Name:10504.txt
# Orginal Text Sentence Count:1202, Orginal Text Word Count:42242
# Text lenght before BERT:188447
# Preprocessed Text Sentence Count:1095, Preprocessed Text Word Count:31787
# Ratio: 0.029
# Summary Sentence Count:32, Summary Word Count:1057
# Summary Word Limit: 930
# New Ratio: 0.028
# New Summary Sentence Count:31, Summary Word Count:1017
# Summary Word Limit: 910
# New Ratio: 0.027
# New Summary Sentence Count:30, Summary Word Count:916
# Document processing time: 12:16
# Total processing time: 01:10:47:16
# ######################################################################################
# 66. Document
# File Name:10505.txt
# Orginal Text Sentence Count:1485, Orginal Text Word Count:50112
# Text lenght before BERT:229424
# Preprocessed Text Sentence Count:1357, Preprocessed Text Word Count:38788
# Ratio: 0.024
# Summary Sentence Count:33, Summary Word Count:977
# Document processing time: 05:06
# Total processing time: 01:10:52:23
# ######################################################################################
# 67. Document
# File Name:10507.txt
# Orginal Text Sentence Count:1656, Orginal Text Word Count:56129
# Text lenght before BERT:253643
# Preprocessed Text Sentence Count:1492, Preprocessed Text Word Count:42457
# Ratio: 0.022
# Summary Sentence Count:32, Summary Word Count:1042
# Summary Word Limit: 930
# New Ratio: 0.021
# New Summary Sentence Count:33, Summary Word Count:1059
# Summary Word Limit: 910
# New Ratio: 0.02
# New Summary Sentence Count:30, Summary Word Count:905
# Document processing time: 16:12
# Total processing time: 01:11:08:35
# ######################################################################################
# 68. Document
# File Name:10514.txt
# Orginal Text Sentence Count:1268, Orginal Text Word Count:44481
# Text lenght before BERT:176442
# Preprocessed Text Sentence Count:1069, Preprocessed Text Word Count:29457
# Ratio: 0.032
# Summary Sentence Count:34, Summary Word Count:1116
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:31, Summary Word Count:1037
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:29, Summary Word Count:961
# Document processing time: 11:38
# Total processing time: 01:11:20:14
# ######################################################################################
# 69. Document
# File Name:10533.txt
# Orginal Text Sentence Count:829, Orginal Text Word Count:29008
# Text lenght before BERT:74970
# Preprocessed Text Sentence Count:408, Preprocessed Text Word Count:11475
# Ratio: 0.082
# Summary Sentence Count:34, Summary Word Count:1024
# Summary Word Limit: 930
# New Ratio: 0.081
# New Summary Sentence Count:34, Summary Word Count:1024
# Summary Word Limit: 910
# New Ratio: 0.079
# New Summary Sentence Count:33, Summary Word Count:874
# Document processing time: 04:36
# Total processing time: 01:11:24:50
# ######################################################################################
# 70. Document
# File Name:10541.txt
# Orginal Text Sentence Count:617, Orginal Text Word Count:24697
# Text lenght before BERT:91821
# Preprocessed Text Sentence Count:540, Preprocessed Text Word Count:15691
# Ratio: 0.06
# Summary Sentence Count:35, Summary Word Count:1110
# Summary Word Limit: 930
# New Ratio: 0.057
# New Summary Sentence Count:32, Summary Word Count:945
# Document processing time: 04:02
# Total processing time: 01:11:28:53
# ######################################################################################
# 71. Document
# File Name:10542.txt
# Orginal Text Sentence Count:650, Orginal Text Word Count:24513
# Text lenght before BERT:84939
# Preprocessed Text Sentence Count:553, Preprocessed Text Word Count:14433
# Ratio: 0.065
# Summary Sentence Count:37, Summary Word Count:963
# Document processing time: 02:00
# Total processing time: 01:11:30:53
# ######################################################################################
# 72. Document
# File Name:10543.txt
# Orginal Text Sentence Count:699, Orginal Text Word Count:25965
# Text lenght before BERT:98597
# Preprocessed Text Sentence Count:614, Preprocessed Text Word Count:16763
# Ratio: 0.056
# Summary Sentence Count:36, Summary Word Count:1024
# Summary Word Limit: 930
# New Ratio: 0.055
# New Summary Sentence Count:34, Summary Word Count:952
# Document processing time: 04:32
# Total processing time: 01:11:35:26
# ######################################################################################
# 73. Document
# File Name:10544.txt
# Orginal Text Sentence Count:1083, Orginal Text Word Count:38485
# Text lenght before BERT:147108
# Preprocessed Text Sentence Count:949, Preprocessed Text Word Count:25206
# Ratio: 0.037
# Summary Sentence Count:36, Summary Word Count:948
# Document processing time: 03:21
# Total processing time: 01:11:38:47
# ######################################################################################
# 74. Document
# File Name:10545.txt
# Orginal Text Sentence Count:1100, Orginal Text Word Count:36934
# Text lenght before BERT:155689
# Preprocessed Text Sentence Count:983, Preprocessed Text Word Count:25991
# Ratio: 0.036
# Summary Sentence Count:36, Summary Word Count:1032
# Summary Word Limit: 930
# New Ratio: 0.035
# New Summary Sentence Count:35, Summary Word Count:1089
# Summary Word Limit: 910
# New Ratio: 0.034
# New Summary Sentence Count:35, Summary Word Count:1089
# Summary Word Limit: 890
# New Ratio: 0.033
# New Summary Sentence Count:34, Summary Word Count:937
# Document processing time: 14:04
# Total processing time: 01:11:52:52
# ######################################################################################
# 75. Document
# File Name:10546.txt
# Orginal Text Sentence Count:1129, Orginal Text Word Count:40038
# Text lenght before BERT:158356
# Preprocessed Text Sentence Count:990, Preprocessed Text Word Count:26190
# Ratio: 0.036
# Summary Sentence Count:37, Summary Word Count:1117
# Summary Word Limit: 930
# New Ratio: 0.033
# New Summary Sentence Count:34, Summary Word Count:996
# Document processing time: 07:09
# Total processing time: 01:12:00:01
# ######################################################################################
# 76. Document
# File Name:10547.txt
# Orginal Text Sentence Count:1067, Orginal Text Word Count:36322
# Text lenght before BERT:153633
# Preprocessed Text Sentence Count:958, Preprocessed Text Word Count:25427
# Ratio: 0.037
# Summary Sentence Count:37, Summary Word Count:1025
# Summary Word Limit: 930
# New Ratio: 0.036
# New Summary Sentence Count:35, Summary Word Count:933
# Document processing time: 06:40
# Total processing time: 01:12:06:42
# ######################################################################################
# 77. Document
# File Name:10548.txt
# Orginal Text Sentence Count:1048, Orginal Text Word Count:37339
# Text lenght before BERT:153957
# Preprocessed Text Sentence Count:957, Preprocessed Text Word Count:25551
# Ratio: 0.037
# Summary Sentence Count:34, Summary Word Count:1056
# Summary Word Limit: 930
# New Ratio: 0.036
# New Summary Sentence Count:33, Summary Word Count:1056
# Summary Word Limit: 910
# New Ratio: 0.035
# New Summary Sentence Count:32, Summary Word Count:1042
# Summary Word Limit: 890
# New Ratio: 0.034
# New Summary Sentence Count:32, Summary Word Count:1023
# Summary Word Limit: 870
# New Ratio: 0.033
# New Summary Sentence Count:31, Summary Word Count:1083
# Summary Word Limit: 850
# New Ratio: 0.032
# New Summary Sentence Count:31, Summary Word Count:1060
# Summary Word Limit: 830
# New Ratio: 0.031
# New Summary Sentence Count:30, Summary Word Count:1021
# Summary Word Limit: 810
# New Ratio: 0.03
# New Summary Sentence Count:28, Summary Word Count:945
# Document processing time: 27:37
# Total processing time: 01:12:34:20
# ######################################################################################
# 78. Document
# File Name:10549.txt
# Orginal Text Sentence Count:1043, Orginal Text Word Count:38966
# Text lenght before BERT:153244
# Preprocessed Text Sentence Count:941, Preprocessed Text Word Count:25775
# Ratio: 0.036
# Summary Sentence Count:34, Summary Word Count:966
# Document processing time: 03:23
# Total processing time: 01:12:37:43
# ######################################################################################
# 79. Document
# File Name:10550.txt
# Orginal Text Sentence Count:1222, Orginal Text Word Count:43747
# Text lenght before BERT:185854
# Preprocessed Text Sentence Count:1116, Preprocessed Text Word Count:30892
# Ratio: 0.03
# Summary Sentence Count:34, Summary Word Count:1055
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:34, Summary Word Count:1040
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:33, Summary Word Count:1016
# Summary Word Limit: 890
# New Ratio: 0.027
# New Summary Sentence Count:32, Summary Word Count:1034
# Summary Word Limit: 870
# New Ratio: 0.026
# New Summary Sentence Count:29, Summary Word Count:923
# Document processing time: 19:49
# Total processing time: 01:12:57:33
# ######################################################################################
# 80. Document
# File Name:10558.txt
# Orginal Text Sentence Count:1494, Orginal Text Word Count:52824
# Text lenght before BERT:218203
# Preprocessed Text Sentence Count:1353, Preprocessed Text Word Count:36814
# Ratio: 0.025
# Summary Sentence Count:34, Summary Word Count:1025
# Summary Word Limit: 930
# New Ratio: 0.024
# New Summary Sentence Count:33, Summary Word Count:992
# Document processing time: 09:30
# Total processing time: 01:13:07:03
# ######################################################################################
# 81. Document
# File Name:1056.txt
# Orginal Text Sentence Count:2687, Orginal Text Word Count:95401
# Text lenght before BERT:397823
# Preprocessed Text Sentence Count:2430, Preprocessed Text Word Count:67508
# Ratio: 0.014
# Summary Sentence Count:37, Summary Word Count:1284
# Summary Word Limit: 930
# New Ratio: 0.011
# New Summary Sentence Count:28, Summary Word Count:999
# Document processing time: 17:38
# Total processing time: 01:13:24:41
# ######################################################################################
# 82. Document
# File Name:10560.txt
# Orginal Text Sentence Count:1888, Orginal Text Word Count:65417
# Text lenght before BERT:287703
# Preprocessed Text Sentence Count:1731, Preprocessed Text Word Count:47805
# Ratio: 0.019
# Summary Sentence Count:33, Summary Word Count:1063
# Summary Word Limit: 930
# New Ratio: 0.018
# New Summary Sentence Count:31, Summary Word Count:1069
# Summary Word Limit: 910
# New Ratio: 0.017
# New Summary Sentence Count:30, Summary Word Count:984
# Document processing time: 18:29
# Total processing time: 01:13:43:11
# ######################################################################################
# 83. Document
# File Name:10561.txt
# Orginal Text Sentence Count:2239, Orginal Text Word Count:74484
# Text lenght before BERT:341505
# Preprocessed Text Sentence Count:2060, Preprocessed Text Word Count:55736
# Ratio: 0.017
# Summary Sentence Count:35, Summary Word Count:1192
# Summary Word Limit: 930
# New Ratio: 0.014
# New Summary Sentence Count:29, Summary Word Count:877
# Document processing time: 14:22
# Total processing time: 01:13:57:33
# ######################################################################################
# 84. Document
# File Name:10563.txt
# Orginal Text Sentence Count:2290, Orginal Text Word Count:82522
# Text lenght before BERT:360928
# Preprocessed Text Sentence Count:2088, Preprocessed Text Word Count:61079
# Ratio: 0.015
# Summary Sentence Count:35, Summary Word Count:1162
# Summary Word Limit: 930
# New Ratio: 0.012
# New Summary Sentence Count:25, Summary Word Count:839
# Document processing time: 15:38
# Total processing time: 01:14:13:12
# ######################################################################################
# 85. Document
# File Name:10564.txt
# Orginal Text Sentence Count:2324, Orginal Text Word Count:83895
# Text lenght before BERT:353453
# Preprocessed Text Sentence Count:2079, Preprocessed Text Word Count:60037
# Ratio: 0.015
# Summary Sentence Count:31, Summary Word Count:1072
# Summary Word Limit: 930
# New Ratio: 0.014
# New Summary Sentence Count:29, Summary Word Count:1084
# Summary Word Limit: 910
# New Ratio: 0.013
# New Summary Sentence Count:26, Summary Word Count:994
# Document processing time: 23:00
# Total processing time: 01:14:36:12
# ######################################################################################
# 86. Document
# File Name:10565.txt
# Orginal Text Sentence Count:2538, Orginal Text Word Count:99966
# Text lenght before BERT:392838
# Preprocessed Text Sentence Count:2266, Preprocessed Text Word Count:68925
# Ratio: 0.013
# Summary Sentence Count:28, Summary Word Count:1054
# Summary Word Limit: 930
# New Ratio: 0.012
# New Summary Sentence Count:28, Summary Word Count:968
# Document processing time: 17:08
# Total processing time: 01:14:53:21
# ######################################################################################
# 87. Document
# File Name:10576.txt
# Orginal Text Sentence Count:1836, Orginal Text Word Count:72107
# Text lenght before BERT:309974
# Preprocessed Text Sentence Count:1653, Preprocessed Text Word Count:51020
# Ratio: 0.018
# Summary Sentence Count:30, Summary Word Count:1209
# Summary Word Limit: 930
# New Ratio: 0.015
# New Summary Sentence Count:25, Summary Word Count:987
# Document processing time: 12:31
# Total processing time: 01:15:05:52
# ...
# Summary Word Limit: 930
# New Ratio: 0.038
# New Summary Sentence Count:32, Summary Word Count:1057
# Summary Word Limit: 910
# New Ratio: 0.037
# New Summary Sentence Count:32, Summary Word Count:1057
# Summary Word Limit: 890
# New Ratio: 0.036
# New Summary Sentence Count:31, Summary Word Count:990
# Document processing time: 13:37
# Total processing time: 02:07:56:00
# ######################################################################################
# 193. Document
# File Name:11521.txt
# Orginal Text Sentence Count:1037, Orginal Text Word Count:37086
# Text lenght before BERT:151652
# Preprocessed Text Sentence Count:892, Preprocessed Text Word Count:25362
# Ratio: 0.037
# Summary Sentence Count:34, Summary Word Count:1021
# Summary Word Limit: 930
# New Ratio: 0.036
# New Summary Sentence Count:33, Summary Word Count:974
# Document processing time: 07:20
# Total processing time: 02:08:03:20
# ######################################################################################
# 194. Document
# File Name:11522.txt
# Orginal Text Sentence Count:1057, Orginal Text Word Count:37284
# Text lenght before BERT:155386
# Preprocessed Text Sentence Count:897, Preprocessed Text Word Count:25967
# Ratio: 0.036
# Summary Sentence Count:33, Summary Word Count:900
# Document processing time: 03:39
# Total processing time: 02:08:07:00
# ######################################################################################
# 195. Document
# File Name:11523.txt
# Orginal Text Sentence Count:1034, Orginal Text Word Count:36655
# Text lenght before BERT:148617
# Preprocessed Text Sentence Count:882, Preprocessed Text Word Count:24756
# Ratio: 0.038
# Summary Sentence Count:36, Summary Word Count:1072
# Summary Word Limit: 930
# New Ratio: 0.037
# New Summary Sentence Count:33, Summary Word Count:1033
# Summary Word Limit: 910
# New Ratio: 0.036
# New Summary Sentence Count:33, Summary Word Count:974
# Document processing time: 11:23
# Total processing time: 02:08:18:23
# ######################################################################################
# 196. Document
# File Name:11531.txt
# Orginal Text Sentence Count:2460, Orginal Text Word Count:87227
# Text lenght before BERT:382366
# Preprocessed Text Sentence Count:2240, Preprocessed Text Word Count:64379
# Ratio: 0.014
# Summary Sentence Count:33, Summary Word Count:1135
# Summary Word Limit: 930
# New Ratio: 0.011
# New Summary Sentence Count:26, Summary Word Count:964
# Document processing time: 19:34
# Total processing time: 02:08:37:58
# ######################################################################################
# 197. Document
# File Name:11562.txt
# Orginal Text Sentence Count:1136, Orginal Text Word Count:43786
# Text lenght before BERT:176369
# Preprocessed Text Sentence Count:976, Preprocessed Text Word Count:29436
# Ratio: 0.032
# Summary Sentence Count:33, Summary Word Count:1153
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:29, Summary Word Count:1000
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:29, Summary Word Count:1013
# Summary Word Limit: 890
# New Ratio: 0.027
# New Summary Sentence Count:28, Summary Word Count:1007
# Summary Word Limit: 870
# New Ratio: 0.026
# New Summary Sentence Count:27, Summary Word Count:961
# Document processing time: 22:06
# Total processing time: 02:09:00:04
# ######################################################################################
# 198. Document
# File Name:11568.txt
# Orginal Text Sentence Count:688, Orginal Text Word Count:27241
# Text lenght before BERT:98627
# Preprocessed Text Sentence Count:582, Preprocessed Text Word Count:16807
# Ratio: 0.056
# Summary Sentence Count:32, Summary Word Count:947
# Document processing time: 02:44
# Total processing time: 02:09:02:48
# ######################################################################################
# 199. Document
# File Name:11574.txt
# Orginal Text Sentence Count:1432, Orginal Text Word Count:52782
# Text lenght before BERT:220410
# Preprocessed Text Sentence Count:1292, Preprocessed Text Word Count:37549
# Ratio: 0.025
# Summary Sentence Count:33, Summary Word Count:1163
# Summary Word Limit: 930
# New Ratio: 0.022
# New Summary Sentence Count:30, Summary Word Count:925
# Document processing time: 12:06
# Total processing time: 02:09:14:54
# ######################################################################################
# 200. Document
# File Name:11578.txt
# Orginal Text Sentence Count:1261, Orginal Text Word Count:51442
# Text lenght before BERT:204643
# Preprocessed Text Sentence Count:1131, Preprocessed Text Word Count:34026
# Ratio: 0.027
# Summary Sentence Count:31, Summary Word Count:976
# Document processing time: 05:17
# Total processing time: 02:09:20:12
# ######################################################################################
# 201. Document
# File Name:11580.txt
# Orginal Text Sentence Count:1669, Orginal Text Word Count:59969
# Text lenght before BERT:251597
# Preprocessed Text Sentence Count:1494, Preprocessed Text Word Count:42404
# Ratio: 0.022
# Summary Sentence Count:34, Summary Word Count:1117
# Summary Word Limit: 930
# New Ratio: 0.019
# New Summary Sentence Count:28, Summary Word Count:918
# Document processing time: 13:10
# Total processing time: 02:09:33:22
# ######################################################################################
# 202. Document
# File Name:1161.txt
# Orginal Text Sentence Count:643, Orginal Text Word Count:25777
# Text lenght before BERT:97859
# Preprocessed Text Sentence Count:556, Preprocessed Text Word Count:16176
# Ratio: 0.058
# Summary Sentence Count:33, Summary Word Count:969
# Document processing time: 02:30
# Total processing time: 02:09:35:53
# ######################################################################################
# 203. Document
# File Name:11613.txt
# Orginal Text Sentence Count:292, Orginal Text Word Count:12878
# Text lenght before BERT:43946
# Preprocessed Text Sentence Count:250, Preprocessed Text Word Count:7628
# Ratio: 0.124
# Summary Sentence Count:30, Summary Word Count:908
# Document processing time: 01:12
# Total processing time: 02:09:37:05
# ######################################################################################
# 204. Document
# File Name:11614.txt
# Orginal Text Sentence Count:402, Orginal Text Word Count:14164
# Text lenght before BERT:59855
# Preprocessed Text Sentence Count:349, Preprocessed Text Word Count:8942
# Ratio: 0.106
# Summary Sentence Count:37, Summary Word Count:828
# Document processing time: 01:42
# Total processing time: 02:09:38:48
# ######################################################################################
# 205. Document
# File Name:11616.txt
# Orginal Text Sentence Count:422, Orginal Text Word Count:19107
# Text lenght before BERT:64791
# Preprocessed Text Sentence Count:360, Preprocessed Text Word Count:11144
# Ratio: 0.085
# Summary Sentence Count:30, Summary Word Count:1008
# Summary Word Limit: 930
# New Ratio: 0.083
# New Summary Sentence Count:30, Summary Word Count:1008
# Summary Word Limit: 910
# New Ratio: 0.081
# New Summary Sentence Count:29, Summary Word Count:896
# Document processing time: 04:54
# Total processing time: 02:09:43:43
# ######################################################################################
# 206. Document
# File Name:11617.txt
# Orginal Text Sentence Count:804, Orginal Text Word Count:33480
# Text lenght before BERT:125903
# Preprocessed Text Sentence Count:704, Preprocessed Text Word Count:21134
# Ratio: 0.044
# Summary Sentence Count:31, Summary Word Count:1044
# Summary Word Limit: 930
# New Ratio: 0.043
# New Summary Sentence Count:31, Summary Word Count:1113
# Summary Word Limit: 910
# New Ratio: 0.04
# New Summary Sentence Count:28, Summary Word Count:1025
# Summary Word Limit: 890
# New Ratio: 0.039
# New Summary Sentence Count:28, Summary Word Count:1025
# Summary Word Limit: 870
# New Ratio: 0.038
# New Summary Sentence Count:27, Summary Word Count:936
# Document processing time: 15:38
# Total processing time: 02:09:59:22
# ######################################################################################
# 207. Document
# File Name:11618.txt
# Orginal Text Sentence Count:747, Orginal Text Word Count:30873
# Text lenght before BERT:114294
# Preprocessed Text Sentence Count:650, Preprocessed Text Word Count:19303
# Ratio: 0.049
# Summary Sentence Count:32, Summary Word Count:1031
# Summary Word Limit: 930
# New Ratio: 0.048
# New Summary Sentence Count:31, Summary Word Count:964
# Document processing time: 06:03
# Total processing time: 02:10:05:25
# ######################################################################################
# 208. Document
# File Name:1162.txt
# Orginal Text Sentence Count:793, Orginal Text Word Count:30897
# Text lenght before BERT:115472
# Preprocessed Text Sentence Count:695, Preprocessed Text Word Count:19145
# Ratio: 0.049
# Summary Sentence Count:34, Summary Word Count:957
# Document processing time: 03:15
# Total processing time: 02:10:08:41
# ######################################################################################
# 209. Document
# File Name:11643.txt
# Orginal Text Sentence Count:1109, Orginal Text Word Count:46349
# Text lenght before BERT:186752
# Preprocessed Text Sentence Count:965, Preprocessed Text Word Count:30709
# Ratio: 0.03
# Summary Sentence Count:35, Summary Word Count:1092
# Summary Word Limit: 930
# New Ratio: 0.029
# New Summary Sentence Count:34, Summary Word Count:1011
# Summary Word Limit: 910
# New Ratio: 0.028
# New Summary Sentence Count:33, Summary Word Count:1068
# Summary Word Limit: 890
# New Ratio: 0.027
# New Summary Sentence Count:32, Summary Word Count:912
# Document processing time: 19:59
# Total processing time: 02:10:28:40
# ######################################################################################
# 210. Document
# File Name:11645.txt
# Orginal Text Sentence Count:1561, Orginal Text Word Count:51192
# Text lenght before BERT:231946
# Preprocessed Text Sentence Count:1404, Preprocessed Text Word Count:38280
# Ratio: 0.024
# Summary Sentence Count:34, Summary Word Count:1070
# Summary Word Limit: 930
# New Ratio: 0.023
# New Summary Sentence Count:33, Summary Word Count:1094
# Summary Word Limit: 910
# New Ratio: 0.022
# New Summary Sentence Count:31, Summary Word Count:995
# Document processing time: 16:49
# Total processing time: 02:10:45:29
# ######################################################################################
# 211. Document
# File Name:11646.txt
# Orginal Text Sentence Count:1297, Orginal Text Word Count:43586
# Text lenght before BERT:192592
# Preprocessed Text Sentence Count:1161, Preprocessed Text Word Count:31891
# Ratio: 0.029
# Summary Sentence Count:34, Summary Word Count:1189
# Summary Word Limit: 930
# New Ratio: 0.026
# New Summary Sentence Count:30, Summary Word Count:1100
# Summary Word Limit: 910
# New Ratio: 0.023
# New Summary Sentence Count:27, Summary Word Count:963
# Document processing time: 13:53
# Total processing time: 02:10:59:23
# ######################################################################################
# 212. Document
# File Name:11690.txt
# Orginal Text Sentence Count:704, Orginal Text Word Count:26095
# Text lenght before BERT:103631
# Preprocessed Text Sentence Count:651, Preprocessed Text Word Count:17904
# Ratio: 0.053
# Summary Sentence Count:35, Summary Word Count:957
# Document processing time: 02:33
# Total processing time: 02:11:01:56
# ######################################################################################
# 213. Document
# File Name:11691.txt
# Orginal Text Sentence Count:766, Orginal Text Word Count:29353
# Text lenght before BERT:116454
# Preprocessed Text Sentence Count:694, Preprocessed Text Word Count:20141
# Ratio: 0.047
# Summary Sentence Count:33, Summary Word Count:945
# Document processing time: 02:51
# Total processing time: 02:11:04:48
# ######################################################################################
# 214. Document
# File Name:11692.txt
# Orginal Text Sentence Count:796, Orginal Text Word Count:31471
# Text lenght before BERT:120423
# Preprocessed Text Sentence Count:731, Preprocessed Text Word Count:20516
# Ratio: 0.046
# Summary Sentence Count:33, Summary Word Count:1158
# Summary Word Limit: 930
# New Ratio: 0.043
# New Summary Sentence Count:32, Summary Word Count:1035
# Summary Word Limit: 910
# New Ratio: 0.042
# New Summary Sentence Count:32, Summary Word Count:1035
# Summary Word Limit: 890
# New Ratio: 0.041
# New Summary Sentence Count:31, Summary Word Count:977
# Document processing time: 11:36
# Total processing time: 02:11:16:24
# ######################################################################################
# 215. Document
# File Name:11693.txt
# Orginal Text Sentence Count:743, Orginal Text Word Count:29459
# Text lenght before BERT:112924
# Preprocessed Text Sentence Count:678, Preprocessed Text Word Count:19237
# Ratio: 0.049
# Summary Sentence Count:35, Summary Word Count:1128
# Summary Word Limit: 930
# New Ratio: 0.046
# New Summary Sentence Count:32, Summary Word Count:1021
# Summary Word Limit: 910
# New Ratio: 0.045
# New Summary Sentence Count:32, Summary Word Count:1021
# Summary Word Limit: 890
# New Ratio: 0.044
# New Summary Sentence Count:29, Summary Word Count:1007
# Summary Word Limit: 870
# New Ratio: 0.043
# New Summary Sentence Count:29, Summary Word Count:1086
# Summary Word Limit: 850
# New Ratio: 0.042
# New Summary Sentence Count:29, Summary Word Count:1086
# Summary Word Limit: 830
# New Ratio: 0.041
# New Summary Sentence Count:28, Summary Word Count:975
# Document processing time: 20:14
# Total processing time: 02:11:36:38
# ######################################################################################
# 216. Document
# File Name:11694.txt
# Orginal Text Sentence Count:702, Orginal Text Word Count:27563
# Text lenght before BERT:109019
# Preprocessed Text Sentence Count:646, Preprocessed Text Word Count:18538
# Ratio: 0.051
# Summary Sentence Count:33, Summary Word Count:1017
# Summary Word Limit: 930
# New Ratio: 0.05
# New Summary Sentence Count:33, Summary Word Count:1017
# Summary Word Limit: 910
# New Ratio: 0.049
# New Summary Sentence Count:32, Summary Word Count:988
# Document processing time: 08:14
# Total processing time: 02:11:44:52
# ######################################################################################
# 217. Document
# File Name:11695.txt
# Orginal Text Sentence Count:773, Orginal Text Word Count:30318
# Text lenght before BERT:122616
# Preprocessed Text Sentence Count:723, Preprocessed Text Word Count:20822
# Ratio: 0.045
# Summary Sentence Count:33, Summary Word Count:957
# Document processing time: 02:59
# Total processing time: 02:11:47:52
# ######################################################################################
# 218. Document
# File Name:11696.txt
# Orginal Text Sentence Count:877, Orginal Text Word Count:33671
# Text lenght before BERT:135110
# Preprocessed Text Sentence Count:812, Preprocessed Text Word Count:22718
# Ratio: 0.041
# Summary Sentence Count:34, Summary Word Count:1044
# Summary Word Limit: 930
# New Ratio: 0.04
# New Summary Sentence Count:33, Summary Word Count:1041
# Summary Word Limit: 910
# New Ratio: 0.039
# New Summary Sentence Count:32, Summary Word Count:1002
# Summary Word Limit: 890
# New Ratio: 0.038
# New Summary Sentence Count:31, Summary Word Count:945
# Document processing time: 13:30
# Total processing time: 02:12:01:22
# ######################################################################################
# 219. Document
# File Name:11698.txt
# Orginal Text Sentence Count:1404, Orginal Text Word Count:56254
# Text lenght before BERT:210586
# Preprocessed Text Sentence Count:1254, Preprocessed Text Word Count:35883
# Ratio: 0.026
# Summary Sentence Count:33, Summary Word Count:1047
# Summary Word Limit: 930
# New Ratio: 0.025
# New Summary Sentence Count:31, Summary Word Count:951
# Document processing time: 10:29
# Total processing time: 02:12:11:52
# ######################################################################################
# 220. Document
# File Name:11699.txt
# Orginal Text Sentence Count:928, Orginal Text Word Count:38016
# Text lenght before BERT:143714
# Preprocessed Text Sentence Count:834, Preprocessed Text Word Count:24334
# Ratio: 0.039
# Summary Sentence Count:34, Summary Word Count:1003
# Summary Word Limit: 930
# New Ratio: 0.038
# New Summary Sentence Count:31, Summary Word Count:1007
# Summary Word Limit: 910
# New Ratio: 0.037
# New Summary Sentence Count:31, Summary Word Count:1027
# Summary Word Limit: 890
# New Ratio: 0.036

# %%
def Average(lst): 
    return sum(lst) / len(lst)

# %%
print("#################################################################")
averageDocumentSentenceCounts = Average(DocumentSentenceCounts)
print("averageDocumentSentenceCounts:",averageDocumentSentenceCounts)

averageDocumentWordCounts = Average(DocumentWordCounts)
print("averageDocumentWordCounts:",averageDocumentWordCounts)

print("#################################################################")
averageAfterPreprocessingDocumentSentenceCounts = Average(AfterPreprocessingDocumentSentenceCounts)
print("averageAfterPreprocessingDocumentSentenceCounts:",averageAfterPreprocessingDocumentSentenceCounts)

averageAfterPreprocessingDocumentWordCounts = Average(AfterPreprocessingDocumentWordCounts)
print("averageAfterPreprocessingDocumentWordCounts:",averageAfterPreprocessingDocumentWordCounts)

print("#################################################################")
averageSummarySentenceCounts = Average(SummarySentenceCounts)
print("averageSummarySentenceCounts:",averageSummarySentenceCounts)

averageSummaryWordCounts = Average(SummaryWordCounts)
print("averageSummaryWordCounts:",averageSummaryWordCounts)

# %%
import os
entries1 = os.listdir('annual_reports')
entries2 = os.listdir('summaries')

def prepare_results(p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(metric, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)


for aggregator in ['Avg']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                           max_n=4,
                           limit_length=True,
                           length_limit=1000,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)

    references=[]

    for x in range(len(entries2)):
        tempfilepath='summaries\\' + entries2[x]
        file = open(tempfilepath, encoding="utf8")
        references.append(file.read())
        
    
    hypothesis=[]

    for x in range(len(entries2)):
        tempfilepath='annual_reports\\' + entries2[x]
        file = open(tempfilepath, encoding="utf8")
        hypothesis.append(file.read())
    
    scores = evaluator.get_scores(hypothesis, references)


    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
            for hypothesis_id, results_per_ref in enumerate(results):
                nb_references = len(results_per_ref['p'])
                for reference_id in range(nb_references):
                    print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                    print('\t' + prepare_results(results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
            print()
        else:
            print(prepare_results(results['p'], results['r'], results['f']))
    print()

# %%
print("#################################################################")

# %%
goldreferences=[]

for x in range(len(entries2)):
    try:
        tempfilepathR='gold_summaries\\' + entries2[x].split(".")[0]+'_1.txt'
        fileR = open(tempfilepathR, encoding="utf8")
        goldreferences.append(fileR.read())


    except:
        print("Missing : ", tempfilepathR)


for aggregator in ['Avg']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                           max_n=4,
                           limit_length=True,
                           length_limit=1000,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)
        
    scores = evaluator.get_scores(hypothesis, goldreferences)

    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
            for hypothesis_id, results_per_ref in enumerate(results):
                nb_references = len(results_per_ref['p'])
                for reference_id in range(nb_references):
                    print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                    print('\t' + prepare_results(results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
            print()
        else:
            print(prepare_results(results['p'], results['r'], results['f']))
    print()

# %%
tempListSentences=[]
tempListWords=[]

for i in range(len(goldreferences)):
    tempListWords.append(textWordCount(goldreferences[i]))
    tempListSentences.append(textSentenceCount(goldreferences[i]))
    

averagetempListSentences = Average(tempListSentences)
print("average gold Summaries_1 Sentence Count:",averagetempListSentences)

averagetempListWords = Average(tempListWords)
print("average gold Summaries_1 Words Count:",averagetempListWords)
print("####################################################################################")

# %%
goldreferences=[]

for x in range(len(entries2)):
    try:
        tempfilepathR='gold_summaries\\' + entries2[x].split(".")[0]+'_2.txt'
        fileR = open(tempfilepathR, encoding="utf8")
        goldreferences.append(fileR.read())


    except:
        print("Missing : ", tempfilepathR)


for aggregator in ['Avg']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                           max_n=4,
                           limit_length=True,
                           length_limit=1000,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)
        
    scores = evaluator.get_scores(hypothesis, goldreferences)

    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
            for hypothesis_id, results_per_ref in enumerate(results):
                nb_references = len(results_per_ref['p'])
                for reference_id in range(nb_references):
                    print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                    print('\t' + prepare_results(results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
            print()
        else:
            print(prepare_results(results['p'], results['r'], results['f']))
    print()

# %%
tempListSentences=[]
tempListWords=[]

for i in range(len(goldreferences)):
    tempListWords.append(textWordCount(goldreferences[i]))
    tempListSentences.append(textSentenceCount(goldreferences[i]))
    

averagetempListSentences = Average(tempListSentences)
print("average gold Summaries_2 Sentence Count:",averagetempListSentences)

averagetempListWords = Average(tempListWords)
print("average gold Summaries_2 Words Count:",averagetempListWords)
print("####################################################################################")

# %%
goldreferences=[]

for x in range(len(entries2)):
    try:
        tempfilepathR='gold_summaries\\' + entries2[x].split(".")[0]+'_3.txt'
        fileR = open(tempfilepathR, encoding="utf8")
        goldreferences.append(fileR.read())


    except:
        print("Missing : ", tempfilepathR)


for aggregator in ['Avg']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                           max_n=4,
                           limit_length=True,
                           length_limit=1000,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)
        
    scores = evaluator.get_scores(hypothesis, goldreferences)

    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
            for hypothesis_id, results_per_ref in enumerate(results):
                nb_references = len(results_per_ref['p'])
                for reference_id in range(nb_references):
                    print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                    print('\t' + prepare_results(results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
            print()
        else:
            print(prepare_results(results['p'], results['r'], results['f']))
    print()

# %%
tempListSentences=[]
tempListWords=[]

for i in range(len(goldreferences)):
    tempListWords.append(textWordCount(goldreferences[i]))
    tempListSentences.append(textSentenceCount(goldreferences[i]))
    

averagetempListSentences = Average(tempListSentences)
print("average gold Summaries_3 Sentence Count:",averagetempListSentences)

averagetempListWords = Average(tempListWords)
print("average gold Summaries_3 Words Count:",averagetempListWords)
print("####################################################################################")

# %%
import os
entries2 = os.listdir('summaries')
entries3 = os.listdir('gold_summaries')
hypothesisAll=[]
goldReferencesAll=[]
onlyName=[]

for item in range(len(entries2)):
    temp=entries2[item].split(".")[0]
    onlyName.append(temp)

count=0
for item in range(len(entries3)):
    if(entries3[item].split("_")[0] in onlyName):
        tempfilepathR='gold_summaries\\' + entries3[item]
        fileR = open(tempfilepathR, encoding="utf8")
        goldReferencesAll.append(fileR.read())
        fileR.close()

        tempfilepathH='annual_reports\\' + entries3[item].split("_")[0]+".txt"
        fileH = open(tempfilepathH, encoding="utf8")
        hypothesisAll.append(fileH.read())
        
for aggregator in ['Avg']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                           max_n=4,
                           limit_length=True,
                           length_limit=1000,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)
        
    scores = evaluator.get_scores(hypothesisAll, goldReferencesAll)

    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
            for hypothesis_id, results_per_ref in enumerate(results):
                nb_references = len(results_per_ref['p'])
                for reference_id in range(nb_references):
                    print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                    print('\t' + prepare_results(results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
            print()
        else:
            print(prepare_results(results['p'], results['r'], results['f']))
    print()

# %%
tempListSentences=[]
tempListWords=[]

for i in range(len(goldReferencesAll)):
    tempListWords.append(textWordCount(goldReferencesAll[i]))
    tempListSentences.append(textSentenceCount(goldReferencesAll[i]))
    

averagetempListSentences = Average(tempListSentences)
print("average gold Summaries All Sentence Count:",averagetempListSentences)

averagetempListWords = Average(tempListWords)
print("average gold Summaries All Words Count:",averagetempListWords)
print("####################################################################################")
